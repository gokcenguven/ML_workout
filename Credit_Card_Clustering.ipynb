# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %%
dataset =pd.read_csv("CreditCard_Dataset.csv")
dataset.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
missing_data = dataset.isna().sum()
print(missing_data)
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
dataset.fillna( dataset.median(),inplace=True)
dataset.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
dataset.drop(["CUST_ID"],axis=1, inplace=True)

# %%
# Standardize data
scaler = StandardScaler() 
scaled_dataset = scaler.fit_transform(dataset) 
# Reducing the dimensions of the data 
scaled_dataset=pd.DataFrame(scaled_dataset)

scaled_dataset.describe()
# Out:
#                  0             1             2             3             4   \
# count  8.950000e+03  8.950000e+03  8.950000e+03  8.950000e+03  8.950000e+03
# mean   4.195651e-16  1.209548e-14 -9.278518e-16  3.916048e-15  2.275424e-15
# std    1.000056e+00  1.000056e+00  1.000056e+00  1.000056e+00  1.000056e+00
# min   -7.516398e-01 -3.703271e+00 -4.695519e-01 -3.569340e-01 -4.545762e-01
# 25%   -6.900078e-01  4.904486e-02 -4.510006e-01 -3.569340e-01 -4.545762e-01
# 50%   -3.320286e-01  5.180838e-01 -3.004541e-01 -3.340396e-01 -3.561562e-01
# 75%    2.352559e-01  5.180838e-01  5.004652e-02 -9.056763e-03  6.366321e-02
# max    8.397489e+00  5.180838e-01  2.248351e+01  2.420107e+01  2.442689e+01
#
#                  5             6             7             8             9   \
# count  8.950000e+03  8.950000e+03  8.950000e+03  8.950000e+03  8.950000e+03
# mean   5.693056e-15 -3.716084e-16  2.021052e-15  2.353921e-16  5.729495e-16
# ...

# %%
pca = PCA(n_components = 2) 
PCA_dataset = pca.fit_transform(scaled_dataset) 
PCA_dataset = pd.DataFrame(PCA_dataset) 
PCA_dataset.columns = ['P1', 'P2'] 
  
PCA_dataset.head()
# Out:
#          P1        P2
# 0 -1.683648 -1.072247
# 1 -1.134081  2.509127
# 2  0.969394 -0.383519
# 3 -0.888218  0.004661
# 4 -1.600021 -0.683805

# %%
#Elbow Criterion
#Taking inertia as evaluation metrics (Dunn index is also Ok)

SSE={}
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1500,init='k-means++').fit(PCA_dataset)
    SSE[k] = kmeans.inertia_ 
plt.figure()
plt.plot(list(SSE.keys()), list(SSE.values()))
plt.xlabel("Number of cluster")
plt.ylabel("Inertia")
plt.show()

# %%
#Silhouette Coefficient Method
#Higher Silhouette Coefficient score =>> better-defined clusters.
Silhouette_Scores = [] 

for n_cluster in range(2, 10):
    Silhouette_Scores.append( 
        silhouette_score(PCA_dataset, KMeans(n_clusters = n_cluster).fit_predict(PCA_dataset))) 
    

k = [2, 3, 4, 5, 6, 7, 8, 9] 
plt.bar(k, Silhouette_Scores) 
plt.xlabel('Number of clusters', fontsize = 10) 
plt.ylabel('Silhouette Score', fontsize = 10) 
plt.show()

# %%
kmeans = KMeans(n_clusters=3,max_iter=1000)
kmeans.fit(PCA_dataset)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1000,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
pred = kmeans.predict(PCA_dataset)
PCA_df = pd.DataFrame(PCA_dataset)
PCA_df["cluster"] = pred
PCA_df["cluster"].value_counts()
# Out:
# 1    6109
# 0    1649
# 2    1192
# Name: cluster, dtype: int64

# %%
# Visualizing the clustering 
plt.scatter(PCA_dataset['P1'], PCA_dataset['P2'],  
           c = KMeans(n_clusters = 3).fit_predict(PCA_dataset)) 
plt.show()

# %%
# Decision boundary. 
x_min, x_max = PCA_dataset['P1'].min() - 1, PCA_dataset['P1'].max() + 1
y_min, y_max = PCA_dataset['P2'].min() - 1, PCA_dataset['P2'].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .01), np.arange(y_min, y_max, .01))

Z = kmeans.predict(np.array(list(zip(xx.ravel(), yy.ravel()))))

Z = Z.reshape(xx.shape)
plt.figure(1)
plt.clf()
plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           aspect='auto', origin='lower')

plt.plot(PCA_dataset['P1'], PCA_dataset['P2'], 'k.', markersize=2)

centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='o', s=10, linewidths=3,
            color='w', zorder=10)
plt.title('K-means Clustering Boundaries + Centroids')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.show()
